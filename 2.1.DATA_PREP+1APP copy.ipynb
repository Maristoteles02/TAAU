# %%
import pandas as pd
import numpy as np
from tools import *
import os
import preprocessor
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipeline
import warnings
from sklearn.model_selection import train_test_split,cross_val_score,  GridSearchCV, KFold, StratifiedKFold, RandomizedSearchCV
warnings.catch_warnings()
# Out:
# catch_warnings()

# %%
df = pd.read_csv('data/diabetic_data.csv')

# %%
preprocessor_eda=preprocessor.Train_preprocessor('data/mapping_json',binary=True)
df=preprocessor_eda.transform(df)
# Out:
# c:\Users\mario\OneDrive\Documentos\TAAU\TAAU\preprocessor.py:151: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diag_1'] = df['diag_1'].map(d).astype(int)
# c:\Users\mario\OneDrive\Documentos\TAAU\TAAU\preprocessor.py:152: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diag_2'] = df['diag_2'].map(d).astype(int)
# c:\Users\mario\OneDrive\Documentos\TAAU\TAAU\preprocessor.py:153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diag_3'] = df['diag_3'].map(d).astype(int)

# %%
df
# Out:
#         gender  diag_1  diag_2  diag_3  insulin  change  diabetesMed  \
# 2            0      10       2      18       -2       0            1
# 3            1       0       2       6        1       1            1
# 4            1       1       1       2        0       1            1
# 6            1       6       6      18        0       1            1
# 8            0       6       6       0        0       1            1
# ...        ...     ...     ...     ...      ...     ...          ...
# 101334       1       6       9      15        0       1            1
# 101342       0       2       1       1       -2       1            1
# 101386       1       6       7       6       -2       1            1
# 101391       1       6       6       6        0       0            1
# 101667       1       6       2       2       -2       1            1
#
#         readmitted  sqrt_n_service_uses  medication/day  \
# 2                0             1.732051        6.500000
# 3                0             0.000000        8.000000
# 4                0             0.000000        8.000000
# 6                0             0.000000        5.250000
# 8                0             0.000000        2.153846
# ...            ...                  ...             ...
# 101334           1             0.000000        1.800000
# 101342           1             1.000000        4.800000
# 101386           1             0.000000        4.750000
# 101391           1             2.236068        3.800000
# 101667           1             0.000000        1.750000
#
#         discharge_disposition_id_home  discharge_disposition_id_hospital  \
# 2                                   1                                  0
# 3                                   1                                  0
# 4                                   1                                  0
# 6                                   1                                  0
# 8                                   1                                  0
# ...                               ...                                ...
# 101334                              1                                  0
# 101342                              1                                  0
# 101386                              1                                  0
# 101391                              1                                  0
# 101667                              0                                  0
#
#         discharge_disposition_id_transfer  admission_type_id_elective  \
# 2                                       0                           0
# 3                                       0                           0
# 4                                       0                           0
# 6                                       0                           1
# 8                                       0                           0
# ...                                   ...                         ...
# 101334                                  0                           0
# 101342                                  0                           0
# 101386                                  0                           0
# 101391                                  0                           0
# 101667                                  1                           0
#
#         admission_type_id_emergency  admission_type_id_newborn  \
# 2                                 1                          0
# 3                                 1                          0
# 4                                 1                          0
# 6                                 0                          0
# 8                                 0                          0
# ...                             ...                        ...
# 101334                            1                          0
# 101342                            0                          0
# 101386                            0                          0
# 101391                            1                          0
# 101667                            1                          0
#
#         admission_type_id_traumat  admission_type_id_urgent
# 2                               0                         0
# 3                               0                         0
# 4                               0                         0
# 6                               0                         0
# 8                               0                         1
# ...                           ...                       ...
# 101334                          0                         0
# 101342                          0                         1
# 101386                          0                         1
# 101391                          0                         0
# 101667                          0                         0
#
# [57176 rows x 18 columns]

# %%
matriz_correlacion = df.corr()

# Ajustando el tamaño de la figura para una mejor visualización
plt.figure(figsize=(10, 8))

# Utilizar Seaborn para una visualización atractiva
sns.heatmap(matriz_correlacion, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)

# Mostrar el gráfico
plt.show()

# %%
df['readmitted'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## SPLIT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57176 entries, 2 to 101667
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             57176 non-null  int32
#  1   diag_1                             57176 non-null  int32
#  2   diag_2                             57176 non-null  int32
#  3   diag_3                             57176 non-null  int32
#  4   insulin                            57176 non-null  int64
#  5   change                             57176 non-null  int64
#  6   diabetesMed                        57176 non-null  int64
#  7   readmitted                         57176 non-null  int32
#  8   sqrt_n_service_uses                57176 non-null  float64
#  9   medication/day                     57176 non-null  float64
#  10  discharge_disposition_id_home      57176 non-null  uint8
#  11  discharge_disposition_id_hospital  57176 non-null  uint8
#  12  discharge_disposition_id_transfer  57176 non-null  uint8
#  13  admission_type_id_elective         57176 non-null  uint8
#  14  admission_type_id_emergency        57176 non-null  uint8
#  15  admission_type_id_newborn          57176 non-null  uint8
#  16  admission_type_id_traumat          57176 non-null  uint8
#  17  admission_type_id_urgent           57176 non-null  uint8
# dtypes: float64(2), int32(5), int64(3), uint8(8)
# memory usage: 4.1 MB

# %%
columns_to_transform=[]
for i in df.columns:
    if df[i].dtype!='int64':
        df[i]=df[i].astype(int)

# %%
df.to_csv('data/final_dataframe.csv')

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn.model_selection import train_test_split

# Cargar tus datos
# data = tu_dataframe

# Separar las características y la variable objetivo
X = df.drop('readmitted', axis=1)
y = df['readmitted']
scaler = StandardScaler()
X = scaler.fit_transform(X)
# Dividir en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,stratify=y, random_state=42)

# Sobremuestreo de la clase minoritaria
ros = RandomOverSampler(random_state=42)
X_train_resampled, y_train_resampled = ros.fit_resample(X_train, y_train)

# Calcular la nueva distribución de clases después del sobremuestreo
class_distribution = Counter(y_train_resampled)
major_class = max(class_distribution, key=class_distribution.get)
reduced_major_class_count = int(class_distribution[major_class] * 0.75)

# Crear un diccionario para la estrategia de submuestreo
sampling_strategy = {major_class: reduced_major_class_count}

# Submuestreo de la clase mayoritaria
rus = RandomUnderSampler(sampling_strategy=sampling_strategy, random_state=42)
X_train_balanced, y_train_balanced = rus.fit_resample(X_train_resampled, y_train_resampled)

print(f"Distribución de clases después del submuestreo: {Counter(y_train_balanced)}")
# Out:
# Distribución de clases después del submuestreo: Counter({0: 26948, 1: 20211})

# %%
from sklearn.dummy import DummyClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn.dummy import DummyClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
#Ejemplo de smote con cv
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.datasets import make_classification, load_breast_cancer

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn.metrics import confusion_matrix,accuracy_score, classification_report, roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
import lightgbm as lgb
classifiers_list = [
  ( 'Baseline',              DummyClassifier() ),
  ( 'Nearest Neighbors (1)', KNeighborsClassifier(1) ),
  ( 'Nearest Neighbors (3)', KNeighborsClassifier(3) ),
  ( 'Nearest Neighbors (5)', KNeighborsClassifier(5) ),
  ( 'Nearest Neighbors (7)', KNeighborsClassifier(7) ),
  ( 'lightGBM',              lgb.LGBMClassifier()    ),
  ( 'Decision Tree',         DecisionTreeClassifier()),
  ( 'Random Forest',         RandomForestClassifier()),
  ( 'Neural Net',            MLPClassifier()         ),
  ( 'AdaBoost',              AdaBoostClassifier()    ),
  ( 'Naive Bayes',           GaussianNB()            ),
  ( 'Logistic Regression',   LogisticRegression()    ),
]

# %%
from scipy.stats import wilcoxon
from sklearn.model_selection import StratifiedKFold, GridSearchCV

# Suponiendo que 'classifiers_list' es una lista de tuplas con nombre y modelo del clasificador
# Y que X_train, y_train, X_test, y_test ya están definidos

valores_auc = {}

# Entrenar y obtener puntuaciones AUC para cada clasificador
for name, model in classifiers_list:
    stratified_kfold = StratifiedKFold(n_splits=10,
                                       shuffle=True,
                                       random_state=11)

    param_grid = {}
    grid_search = GridSearchCV(estimator=model,
                               param_grid=param_grid,
                               scoring='roc_auc_ovr',
                               cv=stratified_kfold,
                               n_jobs=-1)

    grid_search.fit(X_train, y_train)
    valores_auc[name] = [grid_search.cv_results_['split%d_test_score' % i][0] for i in range(10)]

# Realizar la prueba de Wilcoxon para cada par de clasificadores
for name1 in valores_auc:
    for name2 in valores_auc:
        if name1 < name2:  # Esto asegura que cada par se compare solo una vez
            stat, p_value = wilcoxon(valores_auc[name1], valores_auc[name2])
            print(f'Wilcoxon test statistic between {name1} and {name2}: {stat}')
            print(f'P-Value: {p_value}')

            # Interpretar el resultado
            alpha = 0.05
            if p_value > alpha:
                print(f'No hay suficiente evidencia para rechazar la hipótesis nula entre {name1} y {name2} (las distribuciones son similares)')
            else:
                print(f'Rechazar la hipótesis nula entre {name1} y {name2} (las distribuciones son diferentes)')
# Out:
# [LightGBM] [Info] Number of positive: 18792, number of negative: 26948
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001270 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 131
# [LightGBM] [Info] Number of data points in the train set: 45740, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.410844 -> initscore=-0.360478
# [LightGBM] [Info] Start training from score -0.360478
# Wilcoxon test statistic between Baseline and Nearest Neighbors (1): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Nearest Neighbors (1) (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and Nearest Neighbors (3): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Nearest Neighbors (3) (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and Nearest Neighbors (5): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Nearest Neighbors (5) (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and Nearest Neighbors (7): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Nearest Neighbors (7) (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and Decision Tree: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Decision Tree (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and Neural Net: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Neural Net (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and Naive Bayes: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Naive Bayes (las distribuciones son diferentes)
# Wilcoxon test statistic between Baseline and Logistic Regression: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Baseline y Logistic Regression (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (1) and Nearest Neighbors (3): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (1) y Nearest Neighbors (3) (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (1) and Nearest Neighbors (5): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (1) y Nearest Neighbors (5) (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (1) and Nearest Neighbors (7): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (1) y Nearest Neighbors (7) (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (1) and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (1) y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (1) and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (1) y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (1) and Neural Net: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (1) y Neural Net (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (3) and Nearest Neighbors (5): 1.0
# P-Value: 0.00390625
# Rechazar la hipótesis nula entre Nearest Neighbors (3) y Nearest Neighbors (5) (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (3) and Nearest Neighbors (7): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (3) y Nearest Neighbors (7) (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (3) and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (3) y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (3) and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (3) y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (3) and Neural Net: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (3) y Neural Net (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (5) and Nearest Neighbors (7): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (5) y Nearest Neighbors (7) (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (5) and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (5) y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (5) and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (5) y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (5) and Neural Net: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (5) y Neural Net (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (7) and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (7) y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Nearest Neighbors (7) and Random Forest: 9.0
# P-Value: 0.064453125
# No hay suficiente evidencia para rechazar la hipótesis nula entre Nearest Neighbors (7) y Random Forest (las distribuciones son similares)
# Wilcoxon test statistic between Nearest Neighbors (7) and Neural Net: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Nearest Neighbors (7) y Neural Net (las distribuciones son diferentes)
# Wilcoxon test statistic between Decision Tree and Nearest Neighbors (1): 16.0
# P-Value: 0.275390625
# No hay suficiente evidencia para rechazar la hipótesis nula entre Decision Tree y Nearest Neighbors (1) (las distribuciones son similares)
# Wilcoxon test statistic between Decision Tree and Nearest Neighbors (3): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Decision Tree y Nearest Neighbors (3) (las distribuciones son diferentes)
# Wilcoxon test statistic between Decision Tree and Nearest Neighbors (5): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Decision Tree y Nearest Neighbors (5) (las distribuciones son diferentes)
# Wilcoxon test statistic between Decision Tree and Nearest Neighbors (7): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Decision Tree y Nearest Neighbors (7) (las distribuciones son diferentes)
# Wilcoxon test statistic between Decision Tree and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Decision Tree y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Decision Tree and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Decision Tree y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between Decision Tree and Neural Net: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Decision Tree y Neural Net (las distribuciones son diferentes)
# Wilcoxon test statistic between Decision Tree and Naive Bayes: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Decision Tree y Naive Bayes (las distribuciones son diferentes)
# Wilcoxon test statistic between Decision Tree and Logistic Regression: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Decision Tree y Logistic Regression (las distribuciones son diferentes)
# Wilcoxon test statistic between Random Forest and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Random Forest y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Neural Net and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Neural Net y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Neural Net and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Neural Net y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Baseline: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Baseline (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Nearest Neighbors (1): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Nearest Neighbors (1) (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Nearest Neighbors (3): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Nearest Neighbors (3) (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Nearest Neighbors (5): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Nearest Neighbors (5) (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Nearest Neighbors (7): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Nearest Neighbors (7) (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and lightGBM: 3.0
# P-Value: 0.009765625
# Rechazar la hipótesis nula entre AdaBoost y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Decision Tree: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Decision Tree (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Neural Net: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Neural Net (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Naive Bayes: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre AdaBoost y Naive Bayes (las distribuciones son diferentes)
# Wilcoxon test statistic between AdaBoost and Logistic Regression: 3.0
# P-Value: 0.009765625
# Rechazar la hipótesis nula entre AdaBoost y Logistic Regression (las distribuciones son diferentes)
# Wilcoxon test statistic between Naive Bayes and Nearest Neighbors (1): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Naive Bayes y Nearest Neighbors (1) (las distribuciones son diferentes)
# Wilcoxon test statistic between Naive Bayes and Nearest Neighbors (3): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Naive Bayes y Nearest Neighbors (3) (las distribuciones son diferentes)
# Wilcoxon test statistic between Naive Bayes and Nearest Neighbors (5): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Naive Bayes y Nearest Neighbors (5) (las distribuciones son diferentes)
# Wilcoxon test statistic between Naive Bayes and Nearest Neighbors (7): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Naive Bayes y Nearest Neighbors (7) (las distribuciones son diferentes)
# Wilcoxon test statistic between Naive Bayes and lightGBM: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Naive Bayes y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Naive Bayes and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Naive Bayes y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between Naive Bayes and Neural Net: 16.0
# P-Value: 0.275390625
# No hay suficiente evidencia para rechazar la hipótesis nula entre Naive Bayes y Neural Net (las distribuciones son similares)
# Wilcoxon test statistic between Logistic Regression and Nearest Neighbors (1): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Logistic Regression y Nearest Neighbors (1) (las distribuciones son diferentes)
# Wilcoxon test statistic between Logistic Regression and Nearest Neighbors (3): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Logistic Regression y Nearest Neighbors (3) (las distribuciones son diferentes)
# Wilcoxon test statistic between Logistic Regression and Nearest Neighbors (5): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Logistic Regression y Nearest Neighbors (5) (las distribuciones son diferentes)
# Wilcoxon test statistic between Logistic Regression and Nearest Neighbors (7): 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Logistic Regression y Nearest Neighbors (7) (las distribuciones son diferentes)
# Wilcoxon test statistic between Logistic Regression and lightGBM: 1.0
# P-Value: 0.00390625
# Rechazar la hipótesis nula entre Logistic Regression y lightGBM (las distribuciones son diferentes)
# Wilcoxon test statistic between Logistic Regression and Random Forest: 0.0
# P-Value: 0.001953125
# Rechazar la hipótesis nula entre Logistic Regression y Random Forest (las distribuciones son diferentes)
# Wilcoxon test statistic between Logistic Regression and Neural Net: 1.0
# P-Value: 0.00390625
# Rechazar la hipótesis nula entre Logistic Regression y Neural Net (las distribuciones son diferentes)
# Wilcoxon test statistic between Logistic Regression and Naive Bayes: 2.0
# P-Value: 0.005859375
# Rechazar la hipótesis nula entre Logistic Regression y Naive Bayes (las distribuciones son diferentes)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Supongamos que ya tienes un diccionario 'valores_auc' con los resultados de AUC para cada clasificador
# y que cada clasificador ha sido entrenado y validado.

# Realizar la prueba de Wilcoxon para cada par de clasificadores y almacenar los resultados
wilcoxon_results = []

for name1 in valores_auc:
    for name2 in valores_auc:
        if name1 < name2:  # Esto asegura que cada par se compara solo una vez
            stat, p_value = wilcoxon(valores_auc[name1], valores_auc[name2])
            wilcoxon_results.append((name1, name2, stat, p_value))

# Convertir los resultados en un DataFrame para facilitar la visualización
import pandas as pd

results_df = pd.DataFrame(wilcoxon_results, columns=['Classifier1', 'Classifier2', 'Statistic', 'P-Value'])

# Graficar los resultados
plt.figure(figsize=(12, 6))
sns.scatterplot(data=results_df, x='Statistic', y='P-Value', hue='Classifier1', style='Classifier2')
plt.title('Wilcoxon Test Results')
plt.xlabel('Statistic')
plt.ylabel('P-Value')
plt.axhline(0.05, color='red', linestyle='--')  # Línea para el nivel de significancia alfa
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

# valores_auc es un diccionario donde las claves son los nombres de los clasificadores
# y los valores son listas de puntuaciones AUC para cada split
# Ejemplo: valores_auc = {'clasificador1': [0.8, 0.82, ...], 'clasificador2': [0.75, 0.77, ...], ...}

n_splits = 10  # Número de splits en la validación cruzada

plt.figure(figsize=(12, 8))

for name, auc_scores in valores_auc.items():
    plt.plot(range(1, n_splits + 1), auc_scores, marker='o', linestyle='-', label=name)

plt.title('Resultados AUC por Clasificador y Split')
plt.xlabel('Split')
plt.ylabel('AUC')
plt.xticks(range(1, n_splits + 1))
plt.ylim([0.4, 0.7])
plt.legend()
plt.grid(True)
plt.show()

# %%
valores_auc={}

for name, model in classifiers_list:
  stratified_kfold = StratifiedKFold(n_splits=10,
                                        shuffle=True,
                                        random_state=11)

  param_grid = {}
  grid_search = GridSearchCV(estimator=model,
                            param_grid=param_grid,
                            scoring='roc_auc_ovr',
                            cv=stratified_kfold,
                            n_jobs=-1)

  grid_search.fit(X_train, y_train)
  valores_auc[name]=[grid_search.cv_results_['split0_test_score'][0],grid_search.cv_results_['split1_test_score'][0],grid_search.cv_results_['split2_test_score'][0],grid_search.cv_results_['split3_test_score'][0],grid_search.cv_results_['split4_test_score'][0],grid_search.cv_results_['split5_test_score'][0],grid_search.cv_results_['split6_test_score'][0],grid_search.cv_results_['split7_test_score'][0],grid_search.cv_results_['split8_test_score'][0],grid_search.cv_results_['split9_test_score'][0]]
  print(valores_auc)
  cv_score = grid_search.best_score_
  test_score = grid_search.score(X_test, y_test)
  print(f'{name}\nROC AREA CV: {cv_score}\n ROC AREA TEST: {test_score}')
  y_pred=grid_search.predict(X_test)
  roc = roc_curve(y_test, y_pred, pos_label=1)
  sns.lineplot(x=roc[0], y=roc[1])
  sns.lineplot(x=[0,1], y=[0,1], linestyle='--', color='black')
  plt.xlim([0,1])
  plt.ylim([0,1])
  plt.title("ROC"+name)
  plt.show()
# Out:
# {'Baseline': [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]}
# Baseline
# ROC AREA CV: 0.5
#  ROC AREA TEST: 0.5
# {'Baseline': [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5], 'Nearest Neighbors (1)': [0.5359563806093921, 0.5405445908164715, 0.5130795305204184, 0.5163872545002325, 0.518975079508798, 0.533954132235893, 0.5249851646111054, 0.535099098423055, 0.5281147651861557, 0.5277171471423733]}
# Nearest Neighbors (1)
# ROC AREA CV: 0.5274813143553894
#  ROC AREA TEST: 0.526826083511788
# {'Baseline': [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5], 'Nearest Neighbors (1)': [0.5359563806093921, 0.5405445908164715, 0.5130795305204184, 0.5163872545002325, 0.518975079508798, 0.533954132235893, 0.5249851646111054, 0.535099098423055, 0.5281147651861557, 0.5277171471423733], 'Nearest Neighbors (3)': [0.5560544314394478, 0.5544163349602742, 0.5413869336016375, 0.5486579033374441, 0.5506110402940024, 0.560654178938981, 0.5492710664990753, 0.5559844625837176, 0.5467477174236088, 0.5458344893910925]}
# Nearest Neighbors (3)
# ROC AREA CV: 0.5509618558469281
#  ROC AREA TEST: 0.5464299397468795
# {'Baseline': [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.
# Logistic Regression
# ROC AREA CV: 0.6065245600208646
#  ROC AREA TEST: 0.6032640876718727

# %%
valores_acc={}
for name, model in classifiers_list:
  stratified_kfold = StratifiedKFold(n_splits=10,
                                        shuffle=True,
                                        random_state=11)

  param_grid = {}
  grid_search = GridSearchCV(estimator=model,
                            param_grid=param_grid,
                            scoring='accuracy',
                            cv=stratified_kfold,
                            n_jobs=-1)

  grid_search.fit(X_train, y_train)
  valores_acc[name]=[grid_search.cv_results_['split0_test_score'][0],grid_search.cv_results_['split1_test_score'][0],grid_search.cv_results_['split2_test_score'][0],grid_search.cv_results_['split3_test_score'][0],grid_search.cv_results_['split4_test_score'][0],grid_search.cv_results_['split5_test_score'][0],grid_search.cv_results_['split6_test_score'][0],grid_search.cv_results_['split7_test_score'][0],grid_search.cv_results_['split8_test_score'][0],grid_search.cv_results_['split9_test_score'][0]]
  cv_score = grid_search.best_score_
  test_score = grid_search.score(X_test, y_test)
  print(f'{name}\n accuracy CV: {cv_score}\n accuracy TEST: {test_score}')
  prediction_clf=grid_search.predict(X_test)
  cm = confusion_matrix(y_test, prediction_clf)
  sns.heatmap(cm, annot=True,cmap="Blues")
  plt.show()
# Out:
# Baseline
#  accuracy CV: 0.5891560996939222
#  accuracy TEST: 0.5891920251836307
# Nearest Neighbors (1)
#  accuracy CV: 0.5425448185395715
#  accuracy TEST: 0.5425848198670864
# Nearest Neighbors (3)
#  accuracy CV: 0.5602973327503278
#  accuracy TEST: 0.5550017488632389
# Nearest Neighbors (5)
#  accuracy CV: 0.5672715347616966
#  accuracy TEST: 0.5680307799930046
# Nearest Neighbors (7)
#  accuracy CV: 0.5746174027109751
#  accuracy TEST: 0.5738020286813571
# [LightGBM] [Info] Number of positive: 18792, number of negative: 26948
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001097 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 131
# [LightGBM] [Info] Number of data points in the train set: 45740, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.410844 -> initscore=-0.360478
# [LightGBM] [Info] Start training from score -0.360478
# lightGBM
#  accuracy CV: 0.614538696982947
#  accuracy TEST: 0.6203217908359566
# Decision Tree
#  accuracy CV: 0.5526016615653695
#  accuracy TEST: 0.5489681706890521
# Random Forest
#  accuracy CV: 0.5720376038478354
#  accuracy TEST: 0.5733648128716334
# Neural Net
#  accuracy CV: 0.6063620463489287
#  accuracy TEST: 0.6083420776495279
# AdaBoost
#  accuracy CV: 0.6158285964145168
#  accuracy TEST: 0.6176110528156699
# Naive Bayes
#  accuracy CV: 0.41095321381722777
#  accuracy TEST: 0.4117698495977615
# Logistic Regression
#  accuracy CV: 0.6135111499781374
#  accuracy TEST: 0.6125393494228751
