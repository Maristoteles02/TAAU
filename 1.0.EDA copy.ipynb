# %%
import pandas as pd
import numpy as np
from tools import *
import os
import preprocessor

# %%
df = pd.read_csv('data/diabetic_data.csv')

# %%
preprocessor_eda=preprocessor.Train_preprocessor('data/mapping_json')
df=preprocessor_eda.transform_eda(df)
# Out:
# c:\Users\mario\OneDrive\Documentos\TAAU\TAAU\preprocessor.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diag_1'] = df['diag_1'].map(d).astype(int)
# c:\Users\mario\OneDrive\Documentos\TAAU\TAAU\preprocessor.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diag_2'] = df['diag_2'].map(d).astype(int)
# c:\Users\mario\OneDrive\Documentos\TAAU\TAAU\preprocessor.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diag_3'] = df['diag_3'].map(d).astype(int)

# %%
import pandas as pd
import numpy as np

# Suponiendo que df es tu DataFrame
# df = pd.read_csv('tu_archivo.csv')  # Descomenta y ajusta la ruta del archivo si es necesario

# Reemplaza 'NULL', 'null', y '?' con np.nan
df.replace(['NULL', 'null', '?'], np.nan, inplace=True)

# Calcula el porcentaje de valores nulos en cada columna
porcentaje_nulos = df.isnull().mean() * 100

# Filtra y muestra las columnas con más del 10% de valores nulos
columnas_con_nulos_altos = porcentaje_nulos[porcentaje_nulos > 10]

if not columnas_con_nulos_altos.empty:
    print("Columnas con más del 10% de valores nulos:")
    print(columnas_con_nulos_altos)
else:
    print("No hay columnas con más del 10% de valores nulos.")
df=df.drop(columns=['weight','medical_specialty'])
# Out:
# Columnas con más del 10% de valores nulos:
# weight               95.970555
# medical_specialty    48.558370
# dtype: float64

# %%
df
# Out:
#                    race  gender  age admission_type_id  \
# 2       AfricanAmerican       0   25         Emergency
# 3             Caucasian       1   35         Emergency
# 4             Caucasian       1   45         Emergency
# 6             Caucasian       1   65          Elective
# 8             Caucasian       0   85            Urgent
# ...                 ...     ...  ...               ...
# 101342        Caucasian       0   75            Urgent
# 101386        Caucasian       1   75            Urgent
# 101391        Caucasian       1   45         Emergency
# 101667        Caucasian       1   75         Emergency
# 101732              NaN       0   75            Urgent
#
#                                  discharge_disposition_id  \
# 2                                      Discharged to home
# 3                                      Discharged to home
# 4                                      Discharged to home
# 6                                      Discharged to home
# 8                                      Discharged to home
# ...                                                   ...
# 101342  Discharged/transferred to home with home healt...
# 101386                                 Discharged to home
# 101391  Discharged/transferred to home with home healt...
# 101667                      Discharged/transferred to SNF
# 101732                                 Discharged to home
#
#              admission_source_id  time_in_hospital  num_lab_procedures  \
# 2                 Emergency Room                 2                  11
# 3                 Emergency Room                 2                  44
# 4                 Emergency Room                 1                  51
# 6                Clinic Referral                 4                  70
# 8       Transfer from a hospital                13                  68
# ...                          ...               ...                 ...
# 101342        Physician Referral                 5                  52
# 101386        Physician Referral                 4                  20
# 101391            Emergency Room                 5                  64
# 101667            Emergency Room                 4                  37
# 101732        Physician Referral                 4                  41
#
#         num_procedures  num_medications  ...  glipizide-metformin  \
# 2                    5               13  ...                   No
# 3                    1               16  ...                   No
# 4                    0                8  ...                   No
# 6                    1               21  ...                   No
# 8                    2               28  ...                   No
# ...                ...              ...  ...                  ...
# 101342               1               24  ...                   No
# 101386               0               19  ...                   No
# 101391               0               19  ...                   No
# 101667               0                7  ...                   No
# 101732               0               13  ...                   No
#
#         glimepiride-pioglitazone  metformin-rosiglitazone  \
# 2                             No                       No
# 3                             No                       No
# 4                             No                       No
# 6                             No                       No
# 8                             No                       No
# ...                          ...                      ...
# 101342                        No                       No
# 101386                        No                       No
# 101391                        No                       No
# 101667                        No                       No
# 101732                        No                       No
#
#         metformin-pioglitazone change diabetesMed readmitted n_service_uses  \
# 2                           No     No         Yes          2              3
# 3                           No     Ch         Yes          2              0
# 4                           No     Ch         Yes          2              0
# 6                           No     Ch         Yes          2              0
# 8                           No     Ch         Yes          2              0
# ...                        ...    ...         ...        ...            ...
# 101342                      No     Ch         Yes          0              1
# 101386                      No     Ch         Yes          0              0
# 101391                      No     No         Yes          0              5
# 101667                      No     Ch         Yes          0              0
# 101732                      No     Ch         Yes          0              0
#
#        sqrt_n_service_uses medication/day
# 2                 1.732051       6.500000
# 3                 0.000000       8.000000
# 4                 0.000000       8.000000
# 6                 0.000000       5.250000
# 8                 0.000000       2.153846
# ...                    ...            ...
# 101342            1.000000       4.800000
# 101386            0.000000       4.750000
# 101391            2.236068       3.800000
# 101667            0.000000       1.750000
# 101732            0.000000       3.250000
#
# [70233 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 70233 entries, 2 to 101732
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   race                      68358 non-null  object
#  1   gender                    70233 non-null  int32
#  2   age                       70233 non-null  int64
#  3   admission_type_id         65734 non-null  object
#  4   discharge_disposition_id  67795 non-null  object
#  5   admission_source_id       65372 non-null  object
#  6   time_in_hospital          70233 non-null  int64
#  7   num_lab_procedures        70233 non-null  int64
#  8   num_procedures            70233 non-null  int64
#  9   num_medications           70233 non-null  int64
#  10  diag_1                    70233 non-null  int32
#  11  diag_2                    70233 non-null  int32
#  12  diag_3                    70233 non-null  int32
#  13  number_diagnoses          70233 non-null  int64
#  14  max_glu_serum             70233 non-null  object
#  15  A1Cresult                 70233 non-null  object
#  16  metformin                 70233 non-null  object
#  17  repaglinide               70233 non-null  object
#  18  nateglinide               70233 non-null  object
#  19  chlorpropamide            70233 non-null  object
#  20  glimepiride               70233 non-null  object
#  21  acetohexamide             70233 non-null  object
#  22  glipizide                 70233 non-null  object
#  23  glyburide                 70233 non-null  object
#  24  tolbutamide               70233 non-null  object
#  25  pioglitazone              70233 non-null  object
#  26  rosiglitazone             70233 non-null  object
#  27  acarbose                  70233 non-null  object
#  28  miglitol                  70233 non-null  object
#  29  troglitazone              70233 non-null  object
#  30  tolazamide                70233 non-null  object
#  31  examide                   70233 non-null  object
#  32  citoglipton               70233 non-null  object
#  33  insulin                   70233 non-null  object
#  34  glyburide-metformin       70233 non-null  object
#  35  glipizide-metformin       70233 non-null  object
#  36  glimepiride-pioglitazone  70233 non-null  object
#  37  metformin-rosiglitazone   70233 non-null  object
#  38  metformin-pioglitazone    70233 non-null  object
#  39  change                    70233 non-null  object
#  40  diabetesMed               70233 non-null  object
#  41  readmitted                70233 non-null  int32
#  42  n_service_uses            70233 non-null  int64
#  43  sqrt_n_service_uses       70233 non-null  float64
#  44  medication/day            70233 non-null  float64
# dtypes: float64(2), int32(5), int64(7), object(31)
# memory usage: 23.3+ MB

# %% [markdown]
# # Variables review

# %% [markdown]
# ## race

# %%
print(df['race'].value_counts())
print(df['race'].isnull().sum())
df=df.dropna(subset='race')
# Out:
# Caucasian          52638
# AfricanAmerican    12611
# Hispanic            1469
# Other               1157
# Asian                483
# Name: race, dtype: int64
# 1875

# %% [markdown]
# ## time in hospital

# %%
print(df['time_in_hospital'].value_counts())
print(df['time_in_hospital'].isnull().sum())
# Out:
# 3     12096
# 2     11719
# 1     10088
# 4      9163
# 5      6611
# 6      4986
# 7      3865
# 8      2828
# 9      1929
# 10     1517
# 11     1203
# 12      933
# 13      774
# 14      646
# Name: time_in_hospital, dtype: int64
# 0

# %% [markdown]
# # num_lab_procedures

# %%
print(df['num_lab_procedures'].value_counts())
print(df['num_lab_procedures'].isnull().sum())      
df['num_lab_procedures'].hist()
# Out:
# 1      2185
# 43     1837
# 44     1586
# 45     1562
# 46     1481
#        ...
# 107       1
# 120       1
# 121       1
# 118       1
# 132       1
# Name: num_lab_procedures, Length: 116, dtype: int64
# 0
# <Axes: >

# %% [markdown]
# ## diag

# %%
print(df['diag_1'].value_counts())
print(df['diag_1'].isnull().sum())
# Out:
# 6     21124
# 2      6928
# 7      6490
# 8      6155
# 15     5341
# 16     4545
# 12     3875
# 9      3376
# 1      2632
# 0      1760
# 11     1711
# 4      1450
# 18      894
# 5       842
# 3       643
# 10      551
# 13       40
# 17        1
# Name: diag_1, dtype: int64
# 0

# %%
print(df['diag_2'].value_counts())
print(df['diag_2'].isnull().sum())
# Out:
# 6     21558
# 2     14395
# 7      6572
# 9      5053
# 15     3128
# 8      2659
# 11     2153
# 3      2046
# 16     1775
# 4      1773
# 1      1707
# 12     1251
# 0      1238
# 18     1176
# 5       892
# 17      559
# 10      345
# 13       78
# Name: diag_2, dtype: int64
# 0

# %%
print(df['diag_3'].value_counts())
print(df['diag_3'].isnull().sum())
# Out:
# 6     20487
# 2     18685
# 7      4351
# 9      3825
# 15     3051
# 18     2558
# 8      2426
# 4      2102
# 3      1715
# 11     1497
# 16     1392
# 12     1332
# 1      1233
# 5      1229
# 0      1225
# 17      911
# 10      268
# 13       71
# Name: diag_3, dtype: int64
# 0

# %%
df=df.dropna(subset=['diag_1','diag_2','diag_3'])

# %% [markdown]
# ## Medications

# %%
for i in df.columns[16:39]:
    print(df[i].value_counts())
    print(df[i].isnull().sum())
# Out:
# No        54032
# Steady    13120
# Up          793
# Down        413
# Name: metformin, dtype: int64
# 0
# No        67448
# Steady      811
# Up           70
# Down         29
# Name: repaglinide, dtype: int64
# 0
# No        67870
# Steady      464
# Up           16
# Down          8
# Name: nateglinide, dtype: int64
# 0
# No        68289
# Steady       64
# Up            4
# Down          1
# Name: chlorpropamide, dtype: int64
# 0
# No        64782
# Steady     3219
# Up          226
# Down        131
# Name: glimepiride, dtype: int64
# 0
# No        68357
# Steady        1
# Name: acetohexamide, dtype: int64
# 0
# No        59593
# Steady     7836
# Up          566
# Down        363
# Name: glipizide, dtype: int64
# 0
# No        60843
# Steady     6516
# Up          601
# Down        398
# Name: glyburide, dtype: int64
# 0
# No        68340
# Steady       18
# Name: tolbutamide, dtype: int64
# 0
# No        63253
# Steady     4853
# Up          173
# Down         79
# Name: pioglitazone, dtype: int64
# 0
# No        63830
# Steady     4324
# Up          132
# Down         72
# Name: rosiglitazone, dtype: int64
# 0
# No        68164
# Steady      184
# Up           10
# Name: acarbose, dtype: int64
# 0
# No        68338
# Steady       18
# Down          1
# Up            1
# Name: miglitol, dtype: int64
# 0
# No        68355
# Steady        3
# Name: troglitazone, dtype: int64
# 0
# No        68330
# Steady       28
# Name: tolazamide, dtype: int64
# 0
# No    68358
# Name: examide, dtype: int64
# 0
# No    68358
# Name: citoglipton, dtype: int64
# 0
# No        33636
# Steady    20888
# Down       7211
# Up         6623
# Name: insulin, dtype: int64
# 0
# No        67885
# Steady      464
# Up            6
# Down          3
# Name: glyburide-metformin, dtype: int64
# 0
# No        68351
# Steady        7
# Name: glipizide-metformin, dtype: int64
# 0
# No    68358
# Name: glimepiride-pioglitazone, dtype: int64
# 0
# No    68358
# Name: metformin-rosiglitazone, dtype: int64
# 0
# No        68357
# Steady        1
# Name: metformin-pioglitazone, dtype: int64
# 0

# %%
import pandas as pd

# Suponiendo que df es tu DataFrame
# df = pd.read_csv('tu_archivo.csv')  # Descomenta y ajusta la ruta del archivo si es necesario

# Umbral para considerar una distribución desbalanceada (p. ej., 80%)
umbral_desbalance = 0.8

# Identifica y elimina las columnas con distribuciones desbalanceadas
columnas_a_eliminar = []
for columna in df.columns:
    max_freq = df[columna].value_counts(normalize=True).max()
    if max_freq > umbral_desbalance:
        columnas_a_eliminar.append(columna)
        print(f"Columna '{columna}' eliminada: máxima frecuencia = {max_freq}")

# Eliminar las columnas desbalanceadas
df.drop(columns=columnas_a_eliminar, inplace=True)

# Imprimir las columnas que se mantienen
print("Columnas restantes después de la eliminación:")
for columna in df.columns:
    print(columna)
# Out:
# Columna 'max_glu_serum' eliminada: máxima frecuencia = 0.9512566195617191
# Columna 'A1Cresult' eliminada: máxima frecuencia = 0.8210597150296965
# Columna 'repaglinide' eliminada: máxima frecuencia = 0.9866877322332427
# Columna 'nateglinide' eliminada: máxima frecuencia = 0.9928611135492554
# Columna 'chlorpropamide' eliminada: máxima frecuencia = 0.9989906082682349
# Columna 'glimepiride' eliminada: máxima frecuencia = 0.9476871763363469
# Columna 'acetohexamide' eliminada: máxima frecuencia = 0.9999853711343223
# Columna 'glipizide' eliminada: máxima frecuencia = 0.8717779923344744
# Columna 'glyburide' eliminada: máxima frecuencia = 0.8900640744316686
# Columna 'tolbutamide' eliminada: máxima frecuencia = 0.9997366804178004
# Columna 'pioglitazone' eliminada: máxima frecuencia = 0.9253196407150589
# Columna 'rosiglitazone' eliminada: máxima frecuencia = 0.9337604962111238
# Columna 'acarbose' eliminada: máxima frecuencia = 0.9971620000585154
# Columna 'miglitol' eliminada: máxima frecuencia = 0.9997074226864449
# Columna 'troglitazone' eliminada: máxima frecuencia = 0.9999561134029668
# Columna 'tolazamide' eliminada: máxima frecuencia = 0.9995903917610228
# Columna 'examide' eliminada: máxima frecuencia = 1.0
# Columna 'citoglipton' eliminada: máxima frecuencia = 1.0
# Columna 'glyburide-metformin' eliminada: máxima frecuencia = 0.9930805465344217
# Columna 'glipizide-metformin' eliminada: máxima frecuencia = 0.9998975979402557
# Columna 'glimepiride-pioglitazone' eliminada: máxima frecuencia = 1.0
# Columna 'metformin-rosiglitazone' eliminada: máxima frecuencia = 1.0
# Columna 'metformin-pioglitazone' eliminada: máxima frecuencia = 0.9999853711343223
# Columnas restantes después de la eliminación:
# race
# gender
# age
# admission_type_id
# discharge_disposition_id
# admission_source_id
# time_in_hospital
# num_lab_procedures
# num_procedures
# num_medications
# diag_1
# diag_2
# diag_3
# number_diagnoses
# metformin
# insulin
# change
# diabetesMed
# readmitted
# n_service_uses
# sqrt_n_service_uses
# medication/day

# %%
for i in df.columns:
    print(i)
# Out:
# race
# gender
# age
# admission_type_id
# discharge_disposition_id
# admission_source_id
# time_in_hospital
# num_lab_procedures
# num_procedures
# num_medications
# diag_1
# diag_2
# diag_3
# number_diagnoses
# metformin
# insulin
# change
# diabetesMed
# readmitted
# n_service_uses
# sqrt_n_service_uses
# medication/day

# %% [markdown]
# ## change

# %%
print(df['change'].value_counts())
print(df['change'].isnull().sum())
# Out:
# No    37782
# Ch    30576
# Name: change, dtype: int64
# 0

# %% [markdown]
# ## diabetesMed

# %%
print(df['diabetesMed'].value_counts())
print(df['diabetesMed'].isnull().sum())
# Out:
# Yes    51789
# No     16569
# Name: diabetesMed, dtype: int64
# 0

# %%
for i in df.columns:
    print(i,'------>',df[i].dtype)
# Out:
# race ------> object
# gender ------> int32
# age ------> int64
# admission_type_id ------> object
# discharge_disposition_id ------> object
# admission_source_id ------> object
# time_in_hospital ------> int64
# num_lab_procedures ------> int64
# num_procedures ------> int64
# num_medications ------> int64
# diag_1 ------> int32
# diag_2 ------> int32
# diag_3 ------> int32
# number_diagnoses ------> int64
# metformin ------> object
# insulin ------> object
# change ------> object
# diabetesMed ------> object
# readmitted ------> int32
# n_service_uses ------> int64
# sqrt_n_service_uses ------> float64
# medication/day ------> float64

# %%
columns_to_transform=[]
for i in df.columns:
    if df[i].dtype!='int64':
        print(i,'------>',df[i].dtype)
# Out:
# race ------> object
# gender ------> int32
# admission_type_id ------> object
# discharge_disposition_id ------> object
# admission_source_id ------> object
# diag_1 ------> int32
# diag_2 ------> int32
# diag_3 ------> int32
# metformin ------> object
# insulin ------> object
# change ------> object
# diabetesMed ------> object
# readmitted ------> int32
# sqrt_n_service_uses ------> float64
# medication/day ------> float64
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
